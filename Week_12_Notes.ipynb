# %% [markdown]
# # Intro to Machine Learning

# %%
# Dependencies and modules:

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import seaborn as sns
sns.set_theme(style="whitegrid")
import statistics
import math
from scipy import stats

# Import loans_full_schema.csv file for Warm_Up:

loans_full_schema_path = "C:/Users/Nik/Documents/loans_full_schema.csv"
loans_full_schema_df = pd.read_csv(loans_full_schema_path)
loans_full_schema_df.head(2)
# Out:
#                  emp_title  emp_length state homeownership  annual_income  \
# 0  global config engineer          3.0    NJ      MORTGAGE        90000.0
# 1   warehouse office clerk        10.0    HI          RENT        40000.0
#
#   verified_income  debt_to_income  annual_income_joint  \
# 0        Verified           18.01                  NaN
# 1    Not Verified            5.04                  NaN
#
#   verification_income_joint  debt_to_income_joint  ...  sub_grade  \
# 0                       NaN                   NaN  ...         C3
# 1                       NaN                   NaN  ...         C1
#
#    issue_month  loan_status  initial_listing_status  disbursement_method  \
# 0     Mar-2018      Current                   whole                 Cash
# 1     Feb-2018      Current                   whole                 Cash
#
#     balance  paid_total  paid_principal  paid_interest  paid_late_fees
# 0  27015.86     1999.33          984.14        1015.19             0.0
# ...

# %% [markdown]
# # Warm-Up

# %% [markdown]
# Download the csv, store it in a logical location on your computer, convert it to a dataframe, and indicate what your hypothesis is about which factors influence if someone will pay their loan back:

# %%
loans_full_schema_df.sort_values('loan_status', ascending=False)
# Out:
#                               emp_title  emp_length state homeownership  \
# 5516                                NaN         NaN    NY      MORTGAGE
# 8303              respiratory therapist        10.0    DE      MORTGAGE
# 6319                 carpenter foreman          3.0    CA          RENT
# 9595                       electrician          5.0    MS           OWN
# 9440                          marketing         2.0    FL           OWN
# ...                                 ...         ...   ...           ...
# 1344  human resources representative ii         1.0    TN      MORTGAGE
# 8874                                NaN         NaN    MI      MORTGAGE
# 671               senior vice president         9.0    MD      MORTGAGE
# 3957                          president        10.0    NV           OWN
# 6167                   personal trainer         7.0    CA          RENT
#
#       annual_income  verified_income  debt_to_income  annual_income_joint  \
# ...

# %% [markdown]
# Factors that seem to influence the repayment of loans are: debt to income ratio, bankruptcy, sub_grade

# %% [markdown]
# # Notes

# %% [markdown]
# kelvin_df.loc[kelvin_df[‘Monteral’]].isna()
# kelvin_df.loc[kelvin_df[‘Montreal’].isnull()]

# %% [markdown]
# # Lamda function

# %% [markdown]
# https://www.geeksforgeeks.org/applying-lambda-functions-to-pandas-dataframe/
